# %%
import torch
boxes1 = torch.tensor([[10,20,100,100],[30,40,100,100]])
boxes2 = torch.tensor([[23,23,200,200],[23,23,200,200],[23,23,200,200]])

print(boxes1.shape)
print(boxes2.shape)
v1 = boxes1[:,None,:2]
v2 = boxes2[:,:2]
res = torch.max(v1,v2)
print(v1.shape)
print(v2.shape)
print(res.shape)
# print(v1)
# print(v2)
# print(res)
# inter_upperlefts = torch.max(boxes1[:,None,:2],boxes2[:,:2]) 
# print(inter_upperlefts.shape)
# print(inter_upperlefts)
# Out:
# torch.Size([2, 4])
# torch.Size([3, 4])
# torch.Size([2, 1, 2])
# torch.Size([3, 2])
# torch.Size([2, 3, 2])
